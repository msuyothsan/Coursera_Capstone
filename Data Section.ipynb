# %% [markdown]
# Data used in this model is Data-Collisions. The target variable will be "SEVERITYCODE" and the independent variables are "WEATHER", "ROADCOND" and "LIGHTCOND". Modelling will use K-NN, nearest neighbors and logistic regression for prediction.
#
# The Dataset Contains:
#
# 39 input attributes: they contain detailed information about the recorded accidents.
# 1 output attribute: the car accident severity evaluation, which includes all the types of collisions displayed at the intersection or mid-block of a segment.

# %%
import pandas as pd
df = pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.drop(['COLDETKEY','INTKEY', 'SEVERITYCODE.1', 'SEVERITYDESC', 'ADDRTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC','SDOTCOLNUM', 'ST_COLCODE'], axis =1, inplace = True)
df.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY REPORTNO   STATUS  \
# 0             2 -122.323148  47.703140         1    1307  3502005  Matched
# 1             1 -122.347294  47.647172         2   52200  2607959  Matched
# 2             1 -122.334540  47.607871         3   26700  1482393  Matched
# 3             1 -122.334803  47.604803         4    1144  3503937  Matched
# 4             2 -122.306426  47.545739         5   17700  1807429  Matched
#
#                                       LOCATION EXCEPTRSNCODE EXCEPTRSNDESC  \
# 0                   5TH AVE NE AND NE 103RD ST                         NaN
# 1   AURORA BR BETWEEN RAYE ST AND BRIDGE WAY N           NaN           NaN
# 2  4TH AVE BETWEEN SENECA ST AND UNIVERSITY ST           NaN           NaN
# 3     2ND AVE BETWEEN MARION ST AND MADISON ST                         NaN
# 4              SWIFT AVE S AND SWIFT AV OFF RP           NaN           NaN
#
# ...

# %%
df.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY    PERSONCOUNT       PEDCOUNT    PEDCYLCOUNT  \
# count  194673.000000  194673.000000  194673.000000  194673.000000
# mean   141091.456350       2.444427       0.037139       0.028391
# std     86634.402737       1.345929       0.198150       0.167413
# min      1001.000000       0.000000       0.000000       0.000000
# ...
